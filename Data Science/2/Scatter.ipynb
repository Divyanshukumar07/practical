# %%
from matplotlib.pyplot import *

# %%
x = [1, 2, 3, 4, 5]

# %%
y = [5, 7, 10, 2, 1]

# %%
scatter(x, y, color="red", marker="*")
xlabel("X Values")
ylabel("Y Values")
title("Scatter Plot") #title of the graph
grid(True)
show()
