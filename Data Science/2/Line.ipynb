# %%
from matplotlib.pyplot import *

# %%
x = [1, 2, 3, 4, 5]

# %%
y = [2, 3, 5, 7, 11]

# %%
plot(x, y, label= "Prime Numbers", color="green", marker="o")
xlabel("X Axis")
ylabel("Y Axis")
title("Line Plot") 
grid(True)
legend()
show()
