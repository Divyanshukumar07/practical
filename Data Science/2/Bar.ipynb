# %%
from matplotlib.pyplot import *

# %%
Fruits = ["Watermelon", "Orange", "Mango", "Apple", "Banana"]

# %%
Quantities = [2, 7, 10, 2, 12]

# %%
bar(Fruits, Quantities, color="green")
xlabel("Fruits")
ylabel("Quantity")
title("Bar Plot") 
grid(True)
show()
